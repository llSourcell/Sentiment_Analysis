# %%
# !pip install pandas
# !pip install tweepy
# !pip install vaderSentiment
# !pip install tweepy
# !pip install PyHamcrest
# !pip install twython

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

# %%
#My Twitter API Authentication Variables
consumer_key = 'rducoMjhlJyWP3lhx3kE4AqZH'
consumer_secret = 'icuilX2Lw3bka1MistxzrzGQD9ZmYAjDLppGbqC4QpjnUS3Kfv'
access_token = '78296136-7rQlDrgyoU5hHvKyi0hxFi6PL9CbglnYb0ShqPWug'
access_token_secret = '8VVT3Oyr9U75wl889A91GMAgQqkDKrMzKDggVjr3ggKcu'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('beyonce', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  @nanakwekusekyi @hrhmegh @PopCraveNet @Beyonce...
# 1  RT @beygency: Jay Z and Beyoncé accept BRIT Aw...
# 2  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 3  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 4  RT @okayplayer: Beyoncé and JAY-Z accept their...
# 5  RT @PopCraveNet: .@Beyonce and @S_C_ aka The C...
# 6  RT @Carokaylin: And to those who were complain...
# 7  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 8  RT @KarenCivil: Beyoncé &amp; JAY-Z mimic thei...
# 9  Y’all compared us Sussex Fans to the behive.. ...
# 2019-02-20 21:53:54

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\INYANG\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   @nanakwekusekyi @hrhmegh @PopCraveNet @Beyonce...
# 1   RT @beygency: Jay Z and Beyoncé accept BRIT Aw...
# 2   RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 3   RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 4   RT @okayplayer: Beyoncé and JAY-Z accept their...
# 5   RT @PopCraveNet: .@Beyonce and @S_C_ aka The C...
# 6   RT @Carokaylin: And to those who were complain...
# 7   RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 8   RT @KarenCivil: Beyoncé &amp; JAY-Z mimic thei...
# 9   Y’all compared us Sussex Fans to the behive.. ...
# 10  RT @musicnewsfact: Beyoncé and Jay-Z accepting...
# 11  RT @ComplexMusic: Beyoncé and JAY-Z just accep...
# 12  RT @GarrySlay: Beyoncé really accepted a Briti...
# 13  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 14  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# 15  RT @BRITs: Well played @Beyonce &amp; @S_C_ 😂\...
# ...

# %%
type(data['polarity'][4])
data['polarity'][4]
pos = 0
neg = 0
comp = 0
for row in data['polarity']:
    pos += row['pos']
    neg += row['neg']
    comp += row['compound']
    
average_pos = (pos/data['polarity'].size)*100
average_neg = (neg/data['polarity'].size)*100
average_comp = (comp/data['polarity'].size)*100 if (comp/data['polarity'].size)*100 > 0 else 0

print('Positive :',average_pos, 'Negative :', average_neg, 'Compound :', average_comp)
# Out:
# Positive : 20.865000000000006 Negative : 3.6220000000000003 Compound : 38.38780000000003

# %%
plt.bar(height = [average_pos, average_neg, average_comp], x = [ "Good", "Bad", "Compound"])
plt.plot()
# Out:
# []
